# %%
import camelot
import os
import pandas as pd
import glob
import re

# %%
def clean_page_1(df):
    '''
    Cleans and extracts data from page 1 of the PDF.
    
    Inputs:
        df: DataFrame with the raw data extracted from page 1 of the PDF)
    Returns:
        df1: cleaned DataFrame
    
    '''

    # Defined the parameters to extract
    parameters = [
        "Speed (m/s)",
        "Cadence (steps/min)",
        "Steps",
        "Duration (s)",
        "Distance (m)"
    ]
    
        #Lists for foot information, standard deviations and mean value
    foot = ['Both'] * 5
    
    sd = ['NaN'] * 5
    
    values = []
    
    #Use regex to extract all numeric value and store in the list in a sequential order
    
    for index, row in df.iterrows():
        text = str(row[1]).strip()
    
        nums = re.findall(r'\d+\.\d+|\d+', text)
        if len(nums) > 0:
            values.append(nums[0])
    
    
    # print(f"Total number of Extracted Values: {values}")
    
    
    
    # Creates the new dataframe with 'parameters' and 'values' list
    
    df1 = pd.DataFrame(list(zip(parameters, foot, sd, values, )),
                       columns=['Parameter', 'Foot', 'Standard Deviation', 'Mean' ])
    
    df1 = pd.melt(df1, id_vars=['Parameter', 'Foot'],
                  value_vars=['Standard Deviation', 'Mean'],
                  var_name='Statistic', value_name='Value')
    

    

    print("\nPage 1 cleaning is complete")
    # print(df1)
    return df1


def clean_page_3(df):
    
    '''
    Cleans and extracts data from page 1 of the PDF.
    
    Inputs:
        df: DataFrame with the raw data extracted from page 3 of the PDF)
    Returns:
        df3: cleaned DataFrame of page 3
    
    '''
    
    # Define paramers to extract and foot information
    parameters_3 = [
        "Step Length (cm)",
        "Step Length (cm)",
        "Step Width (cm)",
        "Step Width (cm)",
        "Stride Length (cm)",
        "Stride Length (cm)"
        ]
    
    foot_3 = [
    "Left",
    "Right",
    "Left",
    "Right",
    "Left",
    "Right"
    ]
    
    # Empty lists to store extracted value from the PDF
    sd_3 = []
    
    value_3 = []
    
    parameter_number = 3
    
    j = 1 #Column index
    
# Split data at the '+/-' sign to extract mean value and standard deviation separately
    for i in range(parameter_number):
        print(f'in this iteration, j ={j} and i ={i}')
        left_value, left_sd = df.iloc[2, j].split(' ± ')
        right_value,right_sd = df.iloc[3, j].split(' ± ')
                    
# Append data into the empty lists created earlier
        value_3.append(left_value)
        sd_3.append(left_sd)
        value_3.append(right_value)
        sd_3.append(right_sd)
        
        j+=2
        
# Generating a new DataFrame using extracted data
    df3 = pd.DataFrame(list(zip(parameters_3, foot_3, sd_3, value_3, )),
                       columns=['Parameter', 'Foot', 'Standard Deviation', 'Mean' ])
    
    df3 = pd.melt(df3, id_vars=['Parameter', 'Foot'],
                value_vars=['Standard Deviation', 'Mean'],
                var_name='Statistic', value_name='Value')
    
    print("\nPage 3 cleaning is complete")
    return df3
    
    
def clean_page_4(df):
    
    '''
    Cleans and extracts data from page 4 of the PDF.
    
    Inputs:
        df: DataFrame with the raw data extracted from page 4 of the PDF)
    Returns:
        df3: cleaned DataFrame of page 4
    
    '''
    

# Define parameters and foot information
    parameters_4 = [
    "Gait Cycle (s)",
    "Gait Cycle (s)",
    "Swing Phase (s)",
    "Swing Phase (s)",
    "Stance Phase (s)",
    "Stance Phase (s)"
    ]
    foot_4 = [
    "Left",
    "Right",
    "Left",
    "Right",
    "Left",
    "Right"
    ]
    
    value_4 = []
    
    sd_4 = []
    
    j = 1 # Counter to iterates through each column
    k = 2 # Row index for extracting the left foot data
    l = 3 # Row index for extracting right foot data

    for i in range(3):
        
        
        print(f'in this iteration, j ={j} and i ={i}')
        
        R0C0 = df.iloc[0, 0]
        R2C1 = df.iloc[2, 1]
        
## Handle the four different data loyut possibilities


# Possibility 1
        if (R0C0 == '') and (R2C1 ==''):
            # To extract Gait Cycle
            if i == 0:
                print('left : ' + df.iloc[k-1, j+1] )
                print('right : ' + df.iloc[l-1, j+1] )
                
                left_value, left_sd = df.iloc[k-1, j+1].split(' ± ')
                right_value,right_sd = df.iloc[l-1, j+1].split(' ± ')   
            # To extract Swing phase
            if i == 1:
                left_value, left_sd = df.iloc[k+4, j].split(' ± ')
                right_value,right_sd = df.iloc[l+4, j].split(' ± ')      
            #To extract stance phase
            if i == 2:         
                left_value, left_sd = df.iloc[6, 4].split(' ± ')
                right_value,right_sd = df.iloc[7, 4].split(' ± ')                     
# Possbility 2        
        elif R2C1 == '':
            if i == 0:
                print('left : ' + df.iloc[k, j+1])
                print('right : ' + df.iloc[l, j+1])
                      
                left_value, left_sd = df.iloc[k, j+1].split(' ± ')
                right_value,right_sd = df.iloc[l, j+1].split(' ± ')     
            if i == 1:
                left_value, left_sd = df.iloc[k+5, j].split(' ± ')
                right_value,right_sd = df.iloc[l+5, j].split(' ± ')  
            if i == 2:        
                left_value, left_sd = df.iloc[7, 4].split(' ± ')
                right_value,right_sd = df.iloc[8, 4].split(' ± ')          
# Possibility 3          
        elif R0C0 == '':
            if i == 0:
                print('left : ' + df.iloc[k-1, j])
                print('right : ' + df.iloc[l-1, j])
                      
                left_value, left_sd = df.iloc[k-1, j].split(' ± ')
                right_value,right_sd = df.iloc[l-1, j].split(' ± ')   
            if i == 1:
                left_value, left_sd = df.iloc[k+4, j].split(' ± ')
                right_value,right_sd = df.iloc[l+4, j].split(' ± ')  
                 
            if i == 2:        
                left_value, left_sd = df.iloc[6, 4].split(' ± ')
                right_value,right_sd = df.iloc[7, 4].split(' ± ')          
# Possibility 4            
        else:
            if i == 0:
                print('left : ' + df.iloc[k , j])
                print('right : ' + df.iloc[l, j])
                      
                      
                left_value, left_sd = df.iloc[k , j].split(' ± ')
                right_value,right_sd = df.iloc[l, j].split(' ± ')
            if i == 1:
                left_value, left_sd = df.iloc[k + 5 , j].split(' ± ')
                right_value,right_sd = df.iloc[l + 5, j].split(' ± ')        
            if i == 2:        
                left_value, left_sd = df.iloc[7, 4].split(' ± ')
                right_value,right_sd = df.iloc[8, 4].split(' ± ')  
                
# Appending the extracted values to the lists created                
        value_4.append(left_value)
        sd_4.append(left_sd)
        value_4.append(right_value)
        sd_4.append(right_sd)
        
    # Creating a clean DataFrame with the extracted data
        
    df4 = pd.DataFrame(list(zip(parameters_4, foot_4, sd_4, value_4, )),
                    columns=['Parameter', 'Foot', 'Standard Deviation', 'Mean' ])
        
    df4 = pd.melt(df4, id_vars=['Parameter', 'Foot'],
                value_vars=['Standard Deviation', 'Mean'],
                var_name='Statistic', value_name='Value')
    
    print("\nPage 4 cleaning is complete")
    
    return df4
    
def clean_page_18(df):
    print(df)

    '''
        Cleans and extracts data from page 18 of the PDF.
        
        Inputs:
            df: DataFrame with the raw data extracted from page 18 of the PDF)
        Returns:
            df18: cleaned DataFrame of page 18
        
    '''
    
# Predifined list of the parameters and foot infomration of the final DataFrame
    parameters_18 = [
    "Ankle IC Angle (deg)",
    "Ankle IC Angle (deg)",
    "Ankle TC Angle (deg)",
    "Ankle TC Angle (deg)"
    ]
    
    foot_18 = [
    "Left",
    "Right",
    "Left",
    "Right"
    ]
 
    
    value_18 = []
    
    sd_18 = []



    left_value, left_sd = df.iloc[4, 7].split(' ± ')
    right_value,right_sd = df.iloc[5, 7].split(' ± ')

                
# Append data into the empty lists created earlier
    value_18.append(left_value)
    sd_18.append(left_sd)
    value_18.append(right_value)
    sd_18.append(right_sd)
    
    left_value, left_sd = df.iloc[4, 8].split(' ± ')
    right_value,right_sd = df.iloc[5, 8].split(' ± ')
    
    value_18.append(left_value)
    sd_18.append(left_sd)
    value_18.append(right_value)
    sd_18.append(right_sd)

# Create a new DataFrame with the extracted data
    df18 = pd.DataFrame(list(zip(parameters_18, foot_18, sd_18, value_18, )),
                       columns=['Parameter', 'Foot', 'Standard Deviation', 'Mean' ])
        
    df18 = pd.melt(df18, id_vars=['Parameter', 'Foot'],
                value_vars=['Standard Deviation', 'Mean'],
                var_name='Statistic', value_name='Value')
    
    print("\nPage 3 cleaning is complete")
    # print(df18)

    return df18
        
        
     

            
# Mapping the page numbers to their respective cleaning functions
page_cleaning_switch = {
    1: clean_page_1,
    3: clean_page_3,
    4: clean_page_4,
    18: clean_page_18
}


def extract_data_from_pdfs(pdf_dir, pages, output_dir):
    '''
    Extracts and cleans data from specified pages and combines all into a single CSV
    
    Parameters:
        pdf_dir(str) : Directory containing PDF files.
        pages (list): Pages to extract, currentlym only suppurs pages 1,3,4 and 18
        output_dir (str): Directory to save the output CSV file
    '''
    
    
    
    # Find all PDF files in the directory
    pdf_files = glob.glob(os.path.join(pdf_dir, '*.pdf'))

    if not pdf_files:
        print("No PDF files found in the specified directory.")
        return
    
    df_per_trajec = []
    
    
    # List to store all trajectory DataFrames
    combined_trajectory_dfs = []

    # Process each PDF file
    for pdf_file in pdf_files:
        Trajec_name = os.path.basename(pdf_file).split('.')[0].split('-')[0]
        dfs_to_combine = []
        
        
        print(f"\nProcessing file: {pdf_file}")
        

        # Extract tables from specified pages
        tables = camelot.read_pdf(
            pdf_file,
            pages=pages,
            flavor='stream',  # Use 'stream' or 'lattice' depending on your PDFs
            strip_text='\n',  # Remove line breaks within cells
            edge_tol=500,     # Tolerance for table edge detection
            row_tol=20,       # Tolerance for row detection
        )

        if tables.n == 0:
            print(f"    No tables found in {pdf_file} on pages {pages}.")
            continue

        print(f"  Found {tables.n} tables in {pdf_file} on pages {pages}.")

        # Iterate over each extracted table
        for i, table in enumerate(tables, start=1):
            
            df = table.df  # Get the table as a DataFrame
            df = df.dropna(how='all')           # Drop empty rows
            df = df.dropna(axis=1, how='all')   # Drop empty columns

            # Get the page number from the table
            page_number = table.page
            
            # Select the appropriate cleaning function based on page number
            clean_function = page_cleaning_switch.get(page_number)
            if clean_function:
                cleaned_df = clean_function(df)
                dfs_to_combine.append(cleaned_df)
            else:
                print(f"No cleaning function defined for page {page_number}")
                continue
        if dfs_to_combine:    
            df_per_trajec = pd.concat(dfs_to_combine, ignore_index=True)
            
            df_per_trajec = df_per_trajec.rename(columns={'Value': f'{Trajec_name}'})
            print(df_per_trajec)
            
            combined_trajectory_dfs.append(df_per_trajec)   
            
            # Combine all cleaned DataFrames vertically into one DataFrame for the current PDF

    if combined_trajectory_dfs:
        common_columns = combined_trajectory_dfs[0].iloc[:, :3]
        unique_columns = pd.concat([df.iloc[:, 3] for df in combined_trajectory_dfs], axis=1)
        final_df = pd.concat([common_columns, unique_columns], axis=1)
        # final_df = final_df.T
    # print(final_df)
    
            
            # df_per_trajec = pd.concat([common_columns, unique_columns], axis=1 )
    
        
            # # Rename the Values columns to include the trajectory name
            # df_per_trajec = df_per_trajec.rename(columns={
            #     'Value': f'{Trajec_name}'
            # })
            
            
            # # Append the prepared DataFrame to the list
            # combined_trajectory_dfs.append(df_per_trajec)
            # # print(combined_trajectory_dfs)
       
            
    # # Combine all trajectories horizontally
    # final_df = pd.concat(combined_trajectory_dfs, axis=1)

    #     # # Reset index to turn 'Parameter' and 'Foot' back into columns
    #     # final_df = final_df.reset_index()
    # # print(final_df)
        
    final_df.to_csv(output_dir)
            
            

                
                    






               
            
                
            

    

# -----------------------------
# 3. Example Usage
# -----------------------------

pdf_dir = r"C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports"
pages_to_extract = '1,3,4,18'
output_dir = r'C:\Users\yangk\OneDrive\Documents\HATCH\Programming Learning\Gait Report PDF Generator\Extracted Data from MotionCloud Report\extracted_data.csv'

# Call the extraction function
extracted_data = extract_data_from_pdfs(pdf_dir, pages_to_extract, output_dir)
# Out:
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\fast_mid1-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\fast_mid1-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 0.88 ± 0.01
# right : 0.88 ± 0.01
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −11.65  20.87   −4.91  20.87  −11.65  15.17
# 5              Right   −16.54  21.16   −8.08  21.16  −16.54  16.44
# 6         Difference     4.89  −0.29    3.17  −0.29    4.89  −1.27
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     6.25 ± 1.37     −3.75 ± 2.13
# 5     4.34 ± 2.37     −2.22 ± 2.33
# 6            1.91            −1.53
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic fast_mid1
# 0            Speed (m/s)   Both  Standard Deviation       NaN
# 1    Cadence (steps/min)   Both  Standard Deviation       NaN
# 2                  Steps   Both  Standard Deviation       NaN
# 3           Duration (s)   Both  Standard Deviation       NaN
# 4           Distance (m)   Both  Standard Deviation       NaN
# 5            Speed (m/s)   Both                Mean      1.93
# 6    Cadence (steps/min)   Both                Mean    136.50
# 7                  Steps   Both                Mean        45
# 8           Duration (s)   Both                Mean     19.78
# 9           Distance (m)   Both                Mean     38.56
# 10      Step Length (cm)   Left  Standard Deviation      1.85
# 11      Step Length (cm)  Right  Standard Deviation      2.08
# 12       Step Width (cm)   Left  Standard Deviation      1.50
# 13       Step Width (cm)  Right  Standard Deviation      2.43
# 14    Stride Length (cm)   Left  Standard Deviation      2.70
# 15    Stride Length (cm)  Right  Standard Deviation      2.93
# 16      Step Length (cm)   Left                Mean     84.33
# 17      Step Length (cm)  Right                Mean     90.95
# 18       Step Width (cm)   Left                Mean     12.32
# 19       Step Width (cm)  Right                Mean     12.30
# 20    Stride Length (cm)   Left                Mean    175.30
# 21    Stride Length (cm)  Right                Mean    175.48
# 22        Gait Cycle (s)   Left  Standard Deviation      0.01
# 23        Gait Cycle (s)  Right  Standard Deviation      0.01
# 24       Swing Phase (s)   Left  Standard Deviation      0.01
# 25       Swing Phase (s)  Right  Standard Deviation      0.01
# 26      Stance Phase (s)   Left  Standard Deviation      0.01
# 27      Stance Phase (s)  Right  Standard Deviation      0.01
# 28        Gait Cycle (s)   Left                Mean      0.88
# 29        Gait Cycle (s)  Right                Mean      0.88
# 30       Swing Phase (s)   Left                Mean      0.39
# 31       Swing Phase (s)  Right                Mean      0.39
# 32      Stance Phase (s)   Left                Mean      0.49
# 33      Stance Phase (s)  Right                Mean      0.49
# 34  Ankle IC Angle (deg)   Left  Standard Deviation      1.37
# 35  Ankle IC Angle (deg)  Right  Standard Deviation      2.37
# 36  Ankle TC Angle (deg)   Left  Standard Deviation      2.13
# 37  Ankle TC Angle (deg)  Right  Standard Deviation      2.33
# 38  Ankle IC Angle (deg)   Left                Mean      6.25
# 39  Ankle IC Angle (deg)  Right                Mean      4.34
# 40  Ankle TC Angle (deg)   Left                Mean     −3.75
# 41  Ankle TC Angle (deg)  Right                Mean     −2.22
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\fast_short1-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\fast_short1-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 0.89 ± 0.01
# right : 0.89 ± 0.01
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −11.86  20.88   −5.69  20.88  −11.86  14.83
# 5              Right   −19.43  22.55   −7.19  22.55  −19.43  12.80
# 6         Difference     7.58  −1.68    1.50  −1.68    7.58   2.03
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     8.39 ± 1.33     −3.44 ± 2.75
# 5     4.72 ± 2.00     −5.70 ± 4.12
# 6            3.67             2.27
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic fast_short1
# 0            Speed (m/s)   Both  Standard Deviation         NaN
# 1    Cadence (steps/min)   Both  Standard Deviation         NaN
# 2                  Steps   Both  Standard Deviation         NaN
# 3           Duration (s)   Both  Standard Deviation         NaN
# 4           Distance (m)   Both  Standard Deviation         NaN
# 5            Speed (m/s)   Both                Mean        1.94
# 6    Cadence (steps/min)   Both                Mean      135.38
# 7                  Steps   Both                Mean          25
# 8           Duration (s)   Both                Mean       11.08
# 9           Distance (m)   Both                Mean       21.13
# 10      Step Length (cm)   Left  Standard Deviation        2.59
# 11      Step Length (cm)  Right  Standard Deviation        2.19
# 12       Step Width (cm)   Left  Standard Deviation        1.88
# 13       Step Width (cm)  Right  Standard Deviation        1.68
# 14    Stride Length (cm)   Left  Standard Deviation        1.60
# 15    Stride Length (cm)  Right  Standard Deviation        1.88
# 16      Step Length (cm)   Left                Mean       87.09
# 17      Step Length (cm)  Right                Mean       88.96
# 18       Step Width (cm)   Left                Mean       14.45
# 19       Step Width (cm)  Right                Mean       14.77
# 20    Stride Length (cm)   Left                Mean      176.10
# 21    Stride Length (cm)  Right                Mean      176.87
# 22        Gait Cycle (s)   Left  Standard Deviation        0.01
# 23        Gait Cycle (s)  Right  Standard Deviation        0.01
# 24       Swing Phase (s)   Left  Standard Deviation        0.01
# 25       Swing Phase (s)  Right  Standard Deviation        0.01
# 26      Stance Phase (s)   Left  Standard Deviation        0.01
# 27      Stance Phase (s)  Right  Standard Deviation        0.01
# 28        Gait Cycle (s)   Left                Mean        0.89
# 29        Gait Cycle (s)  Right                Mean        0.89
# 30       Swing Phase (s)   Left                Mean        0.39
# 31       Swing Phase (s)  Right                Mean        0.38
# 32      Stance Phase (s)   Left                Mean        0.50
# 33      Stance Phase (s)  Right                Mean        0.50
# 34  Ankle IC Angle (deg)   Left  Standard Deviation        1.33
# 35  Ankle IC Angle (deg)  Right  Standard Deviation        2.00
# 36  Ankle TC Angle (deg)   Left  Standard Deviation        2.75
# 37  Ankle TC Angle (deg)  Right  Standard Deviation        4.12
# 38  Ankle IC Angle (deg)   Left                Mean        8.39
# 39  Ankle IC Angle (deg)  Right                Mean        4.72
# 40  Ankle TC Angle (deg)   Left                Mean       −3.44
# 41  Ankle TC Angle (deg)  Right                Mean       −5.70
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\fast_short2-report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\fast_short2-report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 0.89 ± 0.02
# right : 0.89 ± 0.01
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −14.12  22.06   −9.25  22.06  −14.12  16.23
# 5              Right   −14.79  21.02   −8.43  21.02  −14.79  15.97
# 6         Difference     0.67   1.03   −0.82   1.03    0.67   0.26
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     8.07 ± 2.19     −5.40 ± 3.87
# 5     5.56 ± 2.61     −2.07 ± 2.97
# 6            2.51            −3.33
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic fast_short2
# 0            Speed (m/s)   Both  Standard Deviation         NaN
# 1    Cadence (steps/min)   Both  Standard Deviation         NaN
# 2                  Steps   Both  Standard Deviation         NaN
# 3           Duration (s)   Both  Standard Deviation         NaN
# 4           Distance (m)   Both  Standard Deviation         NaN
# 5            Speed (m/s)   Both                Mean        1.96
# 6    Cadence (steps/min)   Both                Mean      134.29
# 7                  Steps   Both                Mean          25
# 8           Duration (s)   Both                Mean       11.17
# 9           Distance (m)   Both                Mean       21.66
# 10      Step Length (cm)   Left  Standard Deviation        4.38
# 11      Step Length (cm)  Right  Standard Deviation        2.33
# 12       Step Width (cm)   Left  Standard Deviation        2.44
# 13       Step Width (cm)  Right  Standard Deviation        2.17
# 14    Stride Length (cm)   Left  Standard Deviation        5.39
# 15    Stride Length (cm)  Right  Standard Deviation        3.93
# 16      Step Length (cm)   Left                Mean       87.47
# 17      Step Length (cm)  Right                Mean       93.05
# 18       Step Width (cm)   Left                Mean       11.82
# 19       Step Width (cm)  Right                Mean       11.83
# 20    Stride Length (cm)   Left                Mean      180.52
# 21    Stride Length (cm)  Right                Mean      181.41
# 22        Gait Cycle (s)   Left  Standard Deviation        0.02
# 23        Gait Cycle (s)  Right  Standard Deviation        0.01
# 24       Swing Phase (s)   Left  Standard Deviation        0.01
# 25       Swing Phase (s)  Right  Standard Deviation        0.01
# 26      Stance Phase (s)   Left  Standard Deviation        0.01
# 27      Stance Phase (s)  Right  Standard Deviation        0.01
# 28        Gait Cycle (s)   Left                Mean        0.89
# 29        Gait Cycle (s)  Right                Mean        0.89
# 30       Swing Phase (s)   Left                Mean        0.39
# 31       Swing Phase (s)  Right                Mean        0.39
# 32      Stance Phase (s)   Left                Mean        0.50
# 33      Stance Phase (s)  Right                Mean        0.50
# 34  Ankle IC Angle (deg)   Left  Standard Deviation        2.19
# 35  Ankle IC Angle (deg)  Right  Standard Deviation        2.61
# 36  Ankle TC Angle (deg)   Left  Standard Deviation        3.87
# 37  Ankle TC Angle (deg)  Right  Standard Deviation        2.97
# 38  Ankle IC Angle (deg)   Left                Mean        8.07
# 39  Ankle IC Angle (deg)  Right                Mean        5.56
# 40  Ankle TC Angle (deg)   Left                Mean       −5.40
# 41  Ankle TC Angle (deg)  Right                Mean       −2.07
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\normal_long1-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\normal_long1-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.08 ± 0.02
# right : 1.08 ± 0.02
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left    −9.89  22.83   −5.15  22.83   −9.89  12.41
# 5              Right   −16.95  23.74   −7.36  23.74  −16.95  14.41
# 6         Difference     7.06  −0.90    2.22  −0.90    7.06  −2.00
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     3.54 ± 1.89      9.25 ± 1.45
# 5     2.65 ± 1.94      9.93 ± 2.02
# 6            0.89            −0.68
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic normal_long1
# 0            Speed (m/s)   Both  Standard Deviation          NaN
# 1    Cadence (steps/min)   Both  Standard Deviation          NaN
# 2                  Steps   Both  Standard Deviation          NaN
# 3           Duration (s)   Both  Standard Deviation          NaN
# 4           Distance (m)   Both  Standard Deviation          NaN
# 5            Speed (m/s)   Both                Mean         1.30
# 6    Cadence (steps/min)   Both                Mean       111.30
# 7                  Steps   Both                Mean           61
# 8           Duration (s)   Both                Mean        32.88
# 9           Distance (m)   Both                Mean        43.02
# 10      Step Length (cm)   Left  Standard Deviation         1.69
# 11      Step Length (cm)  Right  Standard Deviation         2.22
# 12       Step Width (cm)   Left  Standard Deviation         2.57
# 13       Step Width (cm)  Right  Standard Deviation         2.11
# 14    Stride Length (cm)   Left  Standard Deviation         3.35
# 15    Stride Length (cm)  Right  Standard Deviation         3.57
# 16      Step Length (cm)   Left                Mean        69.92
# 17      Step Length (cm)  Right                Mean        73.49
# 18       Step Width (cm)   Left                Mean        11.39
# 19       Step Width (cm)  Right                Mean        11.46
# 20    Stride Length (cm)   Left                Mean       143.41
# 21    Stride Length (cm)  Right                Mean       143.28
# 22        Gait Cycle (s)   Left  Standard Deviation         0.02
# 23        Gait Cycle (s)  Right  Standard Deviation         0.02
# 24       Swing Phase (s)   Left  Standard Deviation         0.01
# 25       Swing Phase (s)  Right  Standard Deviation         0.01
# 26      Stance Phase (s)   Left  Standard Deviation         0.01
# 27      Stance Phase (s)  Right  Standard Deviation         0.01
# 28        Gait Cycle (s)   Left                Mean         1.08
# 29        Gait Cycle (s)  Right                Mean         1.08
# 30       Swing Phase (s)   Left                Mean         0.47
# 31       Swing Phase (s)  Right                Mean         0.47
# 32      Stance Phase (s)   Left                Mean         0.61
# 33      Stance Phase (s)  Right                Mean         0.61
# 34  Ankle IC Angle (deg)   Left  Standard Deviation         1.89
# 35  Ankle IC Angle (deg)  Right  Standard Deviation         1.94
# 36  Ankle TC Angle (deg)   Left  Standard Deviation         1.45
# 37  Ankle TC Angle (deg)  Right  Standard Deviation         2.02
# 38  Ankle IC Angle (deg)   Left                Mean         3.54
# 39  Ankle IC Angle (deg)  Right                Mean         2.65
# 40  Ankle TC Angle (deg)   Left                Mean         9.25
# 41  Ankle TC Angle (deg)  Right                Mean         9.93
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\normal_long2-gait_report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\normal_long2-gait_report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.05 ± 0.02
# right : 1.06 ± 0.14
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −11.98  21.35   −3.53  21.35  −11.98  10.96
# 5              Right   −15.50  24.70   −4.56  24.70  −15.50  16.11
# 6         Difference     3.51  −3.35    1.03  −3.35    3.51  −5.14
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     4.00 ± 1.52      6.84 ± 1.64
# 5     7.17 ± 2.10      9.77 ± 1.78
# 6           −3.16            −2.93
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic normal_long2
# 0            Speed (m/s)   Both  Standard Deviation          NaN
# 1    Cadence (steps/min)   Both  Standard Deviation          NaN
# 2                  Steps   Both  Standard Deviation          NaN
# 3           Duration (s)   Both  Standard Deviation          NaN
# 4           Distance (m)   Both  Standard Deviation          NaN
# 5            Speed (m/s)   Both                Mean         1.37
# 6    Cadence (steps/min)   Both                Mean       114.06
# 7                  Steps   Both                Mean           59
# 8           Duration (s)   Both                Mean        31.04
# 9           Distance (m)   Both                Mean        43.07
# 10      Step Length (cm)   Left  Standard Deviation         1.98
# 11      Step Length (cm)  Right  Standard Deviation         2.02
# 12       Step Width (cm)   Left  Standard Deviation         2.07
# 13       Step Width (cm)  Right  Standard Deviation         1.59
# 14    Stride Length (cm)   Left  Standard Deviation         3.38
# 15    Stride Length (cm)  Right  Standard Deviation         2.81
# 16      Step Length (cm)   Left                Mean        71.22
# 17      Step Length (cm)  Right                Mean        77.28
# 18       Step Width (cm)   Left                Mean         9.51
# 19       Step Width (cm)  Right                Mean         9.65
# 20    Stride Length (cm)   Left                Mean       148.51
# 21    Stride Length (cm)  Right                Mean       148.81
# 22        Gait Cycle (s)   Left  Standard Deviation         0.02
# 23        Gait Cycle (s)  Right  Standard Deviation         0.14
# 24       Swing Phase (s)   Left  Standard Deviation         0.01
# 25       Swing Phase (s)  Right  Standard Deviation         0.12
# 26      Stance Phase (s)   Left  Standard Deviation         0.01
# 27      Stance Phase (s)  Right  Standard Deviation         0.13
# 28        Gait Cycle (s)   Left                Mean         1.05
# 29        Gait Cycle (s)  Right                Mean         1.06
# 30       Swing Phase (s)   Left                Mean         0.47
# 31       Swing Phase (s)  Right                Mean         0.71
# 32      Stance Phase (s)   Left                Mean         0.59
# 33      Stance Phase (s)  Right                Mean         0.35
# 34  Ankle IC Angle (deg)   Left  Standard Deviation         1.52
# 35  Ankle IC Angle (deg)  Right  Standard Deviation         2.10
# 36  Ankle TC Angle (deg)   Left  Standard Deviation         1.64
# 37  Ankle TC Angle (deg)  Right  Standard Deviation         1.78
# 38  Ankle IC Angle (deg)   Left                Mean         4.00
# 39  Ankle IC Angle (deg)  Right                Mean         7.17
# 40  Ankle TC Angle (deg)   Left                Mean         6.84
# 41  Ankle TC Angle (deg)  Right                Mean         9.77
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\normal_rect1-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\normal_rect1-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.11 ± 0.02
# right : 1.11 ± 0.03
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −13.69  23.04   −4.08  23.04  −13.69  13.14
# 5              Right   −18.70  23.52  −10.32  23.52  −18.70  16.18
# 6         Difference     5.01  −0.47    6.24  −0.47    5.01  −3.04
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     4.46 ± 1.82      5.58 ± 1.99
# 5     1.56 ± 2.62      9.46 ± 3.09
# 6            2.90            −3.88
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic normal_rect1
# 0            Speed (m/s)   Both  Standard Deviation          NaN
# 1    Cadence (steps/min)   Both  Standard Deviation          NaN
# 2                  Steps   Both  Standard Deviation          NaN
# 3           Duration (s)   Both  Standard Deviation          NaN
# 4           Distance (m)   Both  Standard Deviation          NaN
# 5            Speed (m/s)   Both                Mean         1.18
# 6    Cadence (steps/min)   Both                Mean       107.71
# 7                  Steps   Both                Mean          163
# 8           Duration (s)   Both                Mean        90.80
# 9           Distance (m)   Both                Mean       108.02
# 10      Step Length (cm)   Left  Standard Deviation         3.08
# 11      Step Length (cm)  Right  Standard Deviation         4.31
# 12       Step Width (cm)   Left  Standard Deviation         3.31
# 13       Step Width (cm)  Right  Standard Deviation         5.30
# 14    Stride Length (cm)   Left  Standard Deviation         5.34
# 15    Stride Length (cm)  Right  Standard Deviation         8.27
# 16      Step Length (cm)   Left                Mean        63.38
# 17      Step Length (cm)  Right                Mean        71.65
# 18       Step Width (cm)   Left                Mean        11.44
# 19       Step Width (cm)  Right                Mean        12.68
# 20    Stride Length (cm)   Left                Mean       135.42
# 21    Stride Length (cm)  Right                Mean       134.49
# 22        Gait Cycle (s)   Left  Standard Deviation         0.02
# 23        Gait Cycle (s)  Right  Standard Deviation         0.03
# 24       Swing Phase (s)   Left  Standard Deviation         0.01
# 25       Swing Phase (s)  Right  Standard Deviation         0.01
# 26      Stance Phase (s)   Left  Standard Deviation         0.02
# 27      Stance Phase (s)  Right  Standard Deviation         0.02
# 28        Gait Cycle (s)   Left                Mean         1.11
# 29        Gait Cycle (s)  Right                Mean         1.11
# 30       Swing Phase (s)   Left                Mean         0.47
# 31       Swing Phase (s)  Right                Mean         0.47
# 32      Stance Phase (s)   Left                Mean         0.64
# 33      Stance Phase (s)  Right                Mean         0.64
# 34  Ankle IC Angle (deg)   Left  Standard Deviation         1.82
# 35  Ankle IC Angle (deg)  Right  Standard Deviation         2.62
# 36  Ankle TC Angle (deg)   Left  Standard Deviation         1.99
# 37  Ankle TC Angle (deg)  Right  Standard Deviation         3.09
# 38  Ankle IC Angle (deg)   Left                Mean         4.46
# 39  Ankle IC Angle (deg)  Right                Mean         1.56
# 40  Ankle TC Angle (deg)   Left                Mean         5.58
# 41  Ankle TC Angle (deg)  Right                Mean         9.46
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\slow_short1-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\slow_short1-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.29 ± 0.02
# right : 1.29 ± 0.02
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left    −8.23  22.16   −3.00  22.16   −8.23  13.59
# 5              Right   −14.40  22.36   −5.43  22.36  −14.40  15.48
# 6         Difference     6.17  −0.20    2.44  −0.20    6.17  −1.89
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     2.99 ± 1.48      9.02 ± 1.65
# 5     1.88 ± 2.05     12.25 ± 1.73
# 6            1.11            −3.23
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic slow_short1
# 0            Speed (m/s)   Both  Standard Deviation         NaN
# 1    Cadence (steps/min)   Both  Standard Deviation         NaN
# 2                  Steps   Both  Standard Deviation         NaN
# 3           Duration (s)   Both  Standard Deviation         NaN
# 4           Distance (m)   Both  Standard Deviation         NaN
# 5            Speed (m/s)   Both                Mean        0.88
# 6    Cadence (steps/min)   Both                Mean       93.30
# 7                  Steps   Both                Mean          39
# 8           Duration (s)   Both                Mean       25.08
# 9           Distance (m)   Both                Mean       21.87
# 10      Step Length (cm)   Left  Standard Deviation        2.27
# 11      Step Length (cm)  Right  Standard Deviation        2.81
# 12       Step Width (cm)   Left  Standard Deviation        2.05
# 13       Step Width (cm)  Right  Standard Deviation        2.35
# 14    Stride Length (cm)   Left  Standard Deviation        4.35
# 15    Stride Length (cm)  Right  Standard Deviation        4.28
# 16      Step Length (cm)   Left                Mean       53.99
# 17      Step Length (cm)  Right                Mean       61.14
# 18       Step Width (cm)   Left                Mean       11.60
# 19       Step Width (cm)  Right                Mean       11.80
# 20    Stride Length (cm)   Left                Mean      115.18
# 21    Stride Length (cm)  Right                Mean      115.25
# 22        Gait Cycle (s)   Left  Standard Deviation        0.02
# 23        Gait Cycle (s)  Right  Standard Deviation        0.02
# 24       Swing Phase (s)   Left  Standard Deviation        0.01
# 25       Swing Phase (s)  Right  Standard Deviation        0.01
# 26      Stance Phase (s)   Left  Standard Deviation        0.02
# 27      Stance Phase (s)  Right  Standard Deviation        0.01
# 28        Gait Cycle (s)   Left                Mean        1.29
# 29        Gait Cycle (s)  Right                Mean        1.29
# 30       Swing Phase (s)   Left                Mean        0.52
# 31       Swing Phase (s)  Right                Mean        0.52
# 32      Stance Phase (s)   Left                Mean        0.77
# 33      Stance Phase (s)  Right                Mean        0.77
# 34  Ankle IC Angle (deg)   Left  Standard Deviation        1.48
# 35  Ankle IC Angle (deg)  Right  Standard Deviation        2.05
# 36  Ankle TC Angle (deg)   Left  Standard Deviation        1.65
# 37  Ankle TC Angle (deg)  Right  Standard Deviation        1.73
# 38  Ankle IC Angle (deg)   Left                Mean        2.99
# 39  Ankle IC Angle (deg)  Right                Mean        1.88
# 40  Ankle TC Angle (deg)   Left                Mean        9.02
# 41  Ankle TC Angle (deg)  Right                Mean       12.25
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\slow_short2-gait_report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\slow_short2-gait_report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.23 ± 0.02
# right : 1.23 ± 0.02
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left    −6.24  22.07   −3.51  22.07   −6.24  15.61
# 5              Right   −12.91  22.44   −6.98  22.44  −12.91  15.71
# 6         Difference     6.67  −0.37    3.47  −0.37    6.67  −0.09
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     3.19 ± 1.84      7.72 ± 1.80
# 5     0.53 ± 1.85     13.15 ± 1.27
# 6            2.66            −5.44
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic slow_short2
# 0            Speed (m/s)   Both  Standard Deviation         NaN
# 1    Cadence (steps/min)   Both  Standard Deviation         NaN
# 2                  Steps   Both  Standard Deviation         NaN
# 3           Duration (s)   Both  Standard Deviation         NaN
# 4           Distance (m)   Both  Standard Deviation         NaN
# 5            Speed (m/s)   Both                Mean        0.88
# 6    Cadence (steps/min)   Both                Mean       97.74
# 7                  Steps   Both                Mean          41
# 8           Duration (s)   Both                Mean       25.17
# 9           Distance (m)   Both                Mean       22.14
# 10      Step Length (cm)   Left  Standard Deviation        3.82
# 11      Step Length (cm)  Right  Standard Deviation        3.07
# 12       Step Width (cm)   Left  Standard Deviation        2.18
# 13       Step Width (cm)  Right  Standard Deviation        2.34
# 14    Stride Length (cm)   Left  Standard Deviation        6.41
# 15    Stride Length (cm)  Right  Standard Deviation        6.71
# 16      Step Length (cm)   Left                Mean       51.33
# 17      Step Length (cm)  Right                Mean       59.37
# 18       Step Width (cm)   Left                Mean       13.55
# 19       Step Width (cm)  Right                Mean       13.56
# 20    Stride Length (cm)   Left                Mean      110.71
# 21    Stride Length (cm)  Right                Mean      110.36
# 22        Gait Cycle (s)   Left  Standard Deviation        0.02
# 23        Gait Cycle (s)  Right  Standard Deviation        0.02
# 24       Swing Phase (s)   Left  Standard Deviation        0.01
# 25       Swing Phase (s)  Right  Standard Deviation        0.02
# 26      Stance Phase (s)   Left  Standard Deviation        0.01
# 27      Stance Phase (s)  Right  Standard Deviation        0.02
# 28        Gait Cycle (s)   Left                Mean        1.23
# 29        Gait Cycle (s)  Right                Mean        1.23
# 30       Swing Phase (s)   Left                Mean        0.49
# 31       Swing Phase (s)  Right                Mean        0.49
# 32      Stance Phase (s)   Left                Mean        0.74
# 33      Stance Phase (s)  Right                Mean        0.74
# 34  Ankle IC Angle (deg)   Left  Standard Deviation        1.84
# 35  Ankle IC Angle (deg)  Right  Standard Deviation        1.85
# 36  Ankle TC Angle (deg)   Left  Standard Deviation        1.80
# 37  Ankle TC Angle (deg)  Right  Standard Deviation        1.27
# 38  Ankle IC Angle (deg)   Left                Mean        3.19
# 39  Ankle IC Angle (deg)  Right                Mean        0.53
# 40  Ankle TC Angle (deg)   Left                Mean        7.72
# 41  Ankle TC Angle (deg)  Right                Mean       13.15
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\slow_short3-gait reportpdf.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\slow_short3-gait reportpdf.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.23 ± 0.03
# right : 1.23 ± 0.03
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left    −7.66  21.42   −3.39  21.42   −7.66  12.93
# 5              Right   −14.69  22.03   −5.91  22.03  −14.69  15.04
# 6         Difference     7.03  −0.61    2.52  −0.61    7.03  −2.12
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     2.27 ± 0.87      7.39 ± 2.82
# 5     1.21 ± 1.93     11.57 ± 1.75
# 6            1.06            −4.18
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic slow_short3
# 0            Speed (m/s)   Both  Standard Deviation         NaN
# 1    Cadence (steps/min)   Both  Standard Deviation         NaN
# 2                  Steps   Both  Standard Deviation         NaN
# 3           Duration (s)   Both  Standard Deviation         NaN
# 4           Distance (m)   Both  Standard Deviation         NaN
# 5            Speed (m/s)   Both                Mean        0.90
# 6    Cadence (steps/min)   Both                Mean       97.74
# 7                  Steps   Both                Mean          39
# 8           Duration (s)   Both                Mean       23.94
# 9           Distance (m)   Both                Mean       21.29
# 10      Step Length (cm)   Left  Standard Deviation        5.30
# 11      Step Length (cm)  Right  Standard Deviation        5.42
# 12       Step Width (cm)   Left  Standard Deviation        2.04
# 13       Step Width (cm)  Right  Standard Deviation        1.51
# 14    Stride Length (cm)   Left  Standard Deviation       10.56
# 15    Stride Length (cm)  Right  Standard Deviation       10.35
# 16      Step Length (cm)   Left                Mean       52.17
# 17      Step Length (cm)  Right                Mean       59.88
# 18       Step Width (cm)   Left                Mean       12.46
# 19       Step Width (cm)  Right                Mean       12.46
# 20    Stride Length (cm)   Left                Mean      112.04
# 21    Stride Length (cm)  Right                Mean      112.69
# 22        Gait Cycle (s)   Left  Standard Deviation        0.03
# 23        Gait Cycle (s)  Right  Standard Deviation        0.03
# 24       Swing Phase (s)   Left  Standard Deviation        0.01
# 25       Swing Phase (s)  Right  Standard Deviation        0.01
# 26      Stance Phase (s)   Left  Standard Deviation        0.03
# 27      Stance Phase (s)  Right  Standard Deviation        0.03
# 28        Gait Cycle (s)   Left                Mean        1.23
# 29        Gait Cycle (s)  Right                Mean        1.23
# 30       Swing Phase (s)   Left                Mean        0.49
# 31       Swing Phase (s)  Right                Mean        0.49
# 32      Stance Phase (s)   Left                Mean        0.74
# 33      Stance Phase (s)  Right                Mean        0.74
# 34  Ankle IC Angle (deg)   Left  Standard Deviation        0.87
# 35  Ankle IC Angle (deg)  Right  Standard Deviation        1.93
# 36  Ankle TC Angle (deg)   Left  Standard Deviation        2.82
# 37  Ankle TC Angle (deg)  Right  Standard Deviation        1.75
# 38  Ankle IC Angle (deg)   Left                Mean        2.27
# 39  Ankle IC Angle (deg)  Right                Mean        1.21
# 40  Ankle TC Angle (deg)   Left                Mean        7.39
# 41  Ankle TC Angle (deg)  Right                Mean       11.57
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\tennis3-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\tennis3-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.12 ± 0.02
# right : 1.12 ± 0.02
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left    −8.63  22.53   −4.66  22.53   −8.63  12.82
# 5              Right   −20.40  22.48   −7.60  22.48  −20.40  12.15
# 6         Difference    11.77   0.05    2.94   0.05   11.77   0.68
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     4.41 ± 1.45      8.37 ± 2.48
# 5     2.68 ± 1.85      5.85 ± 4.49
# 6            1.72             2.52
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic tennis3
# 0            Speed (m/s)   Both  Standard Deviation     NaN
# 1    Cadence (steps/min)   Both  Standard Deviation     NaN
# 2                  Steps   Both  Standard Deviation     NaN
# 3           Duration (s)   Both  Standard Deviation     NaN
# 4           Distance (m)   Both  Standard Deviation     NaN
# 5            Speed (m/s)   Both                Mean    1.18
# 6    Cadence (steps/min)   Both                Mean  107.14
# 7                  Steps   Both                Mean      40
# 8           Duration (s)   Both                Mean   22.40
# 9           Distance (m)   Both                Mean   24.20
# 10      Step Length (cm)   Left  Standard Deviation    1.53
# 11      Step Length (cm)  Right  Standard Deviation    1.64
# 12       Step Width (cm)   Left  Standard Deviation    2.13
# 13       Step Width (cm)  Right  Standard Deviation    1.99
# 14    Stride Length (cm)   Left  Standard Deviation    3.08
# 15    Stride Length (cm)  Right  Standard Deviation    2.38
# 16      Step Length (cm)   Left                Mean   66.33
# 17      Step Length (cm)  Right                Mean   68.11
# 18       Step Width (cm)   Left                Mean   16.92
# 19       Step Width (cm)  Right                Mean   16.51
# 20    Stride Length (cm)   Left                Mean  134.35
# 21    Stride Length (cm)  Right                Mean  134.58
# 22        Gait Cycle (s)   Left  Standard Deviation    0.02
# 23        Gait Cycle (s)  Right  Standard Deviation    0.02
# 24       Swing Phase (s)   Left  Standard Deviation    0.01
# 25       Swing Phase (s)  Right  Standard Deviation    0.02
# 26      Stance Phase (s)   Left  Standard Deviation    0.01
# 27      Stance Phase (s)  Right  Standard Deviation    0.01
# 28        Gait Cycle (s)   Left                Mean    1.12
# 29        Gait Cycle (s)  Right                Mean    1.12
# 30       Swing Phase (s)   Left                Mean    0.47
# 31       Swing Phase (s)  Right                Mean    0.46
# 32      Stance Phase (s)   Left                Mean    0.64
# 33      Stance Phase (s)  Right                Mean    0.66
# 34  Ankle IC Angle (deg)   Left  Standard Deviation    1.45
# 35  Ankle IC Angle (deg)  Right  Standard Deviation    1.85
# 36  Ankle TC Angle (deg)   Left  Standard Deviation    2.48
# 37  Ankle TC Angle (deg)  Right  Standard Deviation    4.49
# 38  Ankle IC Angle (deg)   Left                Mean    4.41
# 39  Ankle IC Angle (deg)  Right                Mean    2.68
# 40  Ankle TC Angle (deg)   Left                Mean    8.37
# 41  Ankle TC Angle (deg)  Right                Mean    5.85
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\tennis4_gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\tennis4_gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.13 ± 0.02
# right : 1.13 ± 0.02
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −10.68  21.65   −3.97  21.65  −10.68  13.28
# 5              Right   −22.20  22.73   −4.78  22.73  −22.20  13.22
# 6         Difference    11.53  −1.08    0.82  −1.08   11.53   0.06
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     4.08 ± 1.57      7.90 ± 3.56
# 5     3.08 ± 0.98      7.63 ± 4.01
# 6            1.00             0.27
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic tennis4_gait report
# 0            Speed (m/s)   Both  Standard Deviation                 NaN
# 1    Cadence (steps/min)   Both  Standard Deviation                 NaN
# 2                  Steps   Both  Standard Deviation                 NaN
# 3           Duration (s)   Both  Standard Deviation                 NaN
# 4           Distance (m)   Both  Standard Deviation                 NaN
# 5            Speed (m/s)   Both                Mean                1.16
# 6    Cadence (steps/min)   Both                Mean              106.25
# 7                  Steps   Both                Mean                  40
# 8           Duration (s)   Both                Mean               22.59
# 9           Distance (m)   Both                Mean               23.93
# 10      Step Length (cm)   Left  Standard Deviation                2.56
# 11      Step Length (cm)  Right  Standard Deviation                2.44
# 12       Step Width (cm)   Left  Standard Deviation                2.05
# 13       Step Width (cm)  Right  Standard Deviation                2.29
# 14    Stride Length (cm)   Left  Standard Deviation                4.22
# 15    Stride Length (cm)  Right  Standard Deviation                4.67
# 16      Step Length (cm)   Left                Mean               66.26
# 17      Step Length (cm)  Right                Mean               66.67
# 18       Step Width (cm)   Left                Mean               15.25
# 19       Step Width (cm)  Right                Mean               15.76
# 20    Stride Length (cm)   Left                Mean              133.49
# 21    Stride Length (cm)  Right                Mean              132.85
# 22        Gait Cycle (s)   Left  Standard Deviation                0.02
# 23        Gait Cycle (s)  Right  Standard Deviation                0.02
# 24       Swing Phase (s)   Left  Standard Deviation                0.01
# 25       Swing Phase (s)  Right  Standard Deviation                0.01
# 26      Stance Phase (s)   Left  Standard Deviation                0.01
# 27      Stance Phase (s)  Right  Standard Deviation                0.01
# 28        Gait Cycle (s)   Left                Mean                1.13
# 29        Gait Cycle (s)  Right                Mean                1.13
# 30       Swing Phase (s)   Left                Mean                0.48
# 31       Swing Phase (s)  Right                Mean                0.47
# 32      Stance Phase (s)   Left                Mean                0.65
# 33      Stance Phase (s)  Right                Mean                0.66
# 34  Ankle IC Angle (deg)   Left  Standard Deviation                1.57
# 35  Ankle IC Angle (deg)  Right  Standard Deviation                0.98
# 36  Ankle TC Angle (deg)   Left  Standard Deviation                3.56
# 37  Ankle TC Angle (deg)  Right  Standard Deviation                4.01
# 38  Ankle IC Angle (deg)   Left                Mean                4.08
# 39  Ankle IC Angle (deg)  Right                Mean                3.08
# 40  Ankle TC Angle (deg)   Left                Mean                7.90
# 41  Ankle TC Angle (deg)  Right                Mean                7.63
#
# Processing file: C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\tennis5-gait report.pdf
#   Found 4 tables in C:\Users\yangk\OneDrive - National University of Singapore\P013 SmartSole\60. Verification testing\TEST-003B\Results\MotionCloud Reports\tennis5-gait report.pdf on pages 1,3,4,18.
#
# Page 1 cleaning is complete
# in this iteration, j =1 and i =0
# in this iteration, j =3 and i =1
# in this iteration, j =5 and i =2
#
# Page 3 cleaning is complete
# in this iteration, j =1 and i =0
# left : 1.09 ± 0.02
# right : 1.10 ± 0.02
# in this iteration, j =1 and i =1
# in this iteration, j =1 and i =2
#
# Page 4 cleaning is complete
#                    0        1      2       3      4       5      6  \
# 0   3.3  Ankle angle
# 1      Ankle Flexion
# 2  Joint angle [deg]  Overall         Stance          Swing
# 3                         Min    Max     Min    Max     Min    Max
# 4               Left   −13.02  20.66   −2.82  20.66  −13.02  12.28
# 5              Right   −16.94  22.00   −4.29  22.00  −16.94  13.61
# 6         Difference     3.92  −1.34    1.47  −1.34    3.92  −1.34
#
#                 7                8
# 0
# 1
# 2
# 3  At foot strike  At foot release
# 4     5.46 ± 1.43      3.22 ± 3.31
# 5     3.45 ± 2.10      7.24 ± 1.96
# 6            2.01            −4.01
#
# Page 3 cleaning is complete
#                Parameter   Foot           Statistic tennis5
# 0            Speed (m/s)   Both  Standard Deviation     NaN
# 1    Cadence (steps/min)   Both  Standard Deviation     NaN
# 2                  Steps   Both  Standard Deviation     NaN
# 3           Duration (s)   Both  Standard Deviation     NaN
# 4           Distance (m)   Both  Standard Deviation     NaN
# 5            Speed (m/s)   Both                Mean    1.27
# 6    Cadence (steps/min)   Both                Mean  109.54
# 7                  Steps   Both                Mean      27
# 8           Duration (s)   Both                Mean   14.79
# 9           Distance (m)   Both                Mean   17.02
# 10      Step Length (cm)   Left  Standard Deviation    2.17
# 11      Step Length (cm)  Right  Standard Deviation    2.36
# 12       Step Width (cm)   Left  Standard Deviation    1.87
# 13       Step Width (cm)  Right  Standard Deviation    1.82
# 14    Stride Length (cm)   Left  Standard Deviation    4.31
# 15    Stride Length (cm)  Right  Standard Deviation    4.35
# 16      Step Length (cm)   Left                Mean   67.37
# 17      Step Length (cm)  Right                Mean   74.48
# 18       Step Width (cm)   Left                Mean    9.95
# 19       Step Width (cm)  Right                Mean    9.72
# 20    Stride Length (cm)   Left                Mean  141.85
# 21    Stride Length (cm)  Right                Mean  142.06
# 22        Gait Cycle (s)   Left  Standard Deviation    0.02
# 23        Gait Cycle (s)  Right  Standard Deviation    0.02
# 24       Swing Phase (s)   Left  Standard Deviation    0.02
# 25       Swing Phase (s)  Right  Standard Deviation    0.01
# 26      Stance Phase (s)   Left  Standard Deviation    0.01
# 27      Stance Phase (s)  Right  Standard Deviation    0.02
# 28        Gait Cycle (s)   Left                Mean    1.09
# 29        Gait Cycle (s)  Right                Mean    1.10
# 30       Swing Phase (s)   Left                Mean    0.46
# 31       Swing Phase (s)  Right                Mean    0.46
# 32      Stance Phase (s)   Left                Mean    0.63
# 33      Stance Phase (s)  Right                Mean    0.63
# 34  Ankle IC Angle (deg)   Left  Standard Deviation    1.43
# 35  Ankle IC Angle (deg)  Right  Standard Deviation    2.10
# 36  Ankle TC Angle (deg)   Left  Standard Deviation    3.31
# 37  Ankle TC Angle (deg)  Right  Standard Deviation    1.96
# 38  Ankle IC Angle (deg)   Left                Mean    5.46
# 39  Ankle IC Angle (deg)  Right                Mean    3.45
# 40  Ankle TC Angle (deg)   Left                Mean    3.22
# 41  Ankle TC Angle (deg)  Right                Mean    7.24
